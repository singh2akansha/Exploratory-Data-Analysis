# %% [markdown]
# ### 1. Load and clean data

# %%
import pandas as pd
import seaborn as sns
import math
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### 2. univariate Analysis

# %%
plt.figure(figsize=(12,8))
sns.displot(x='Insulin',hue='Outcome',data=df,bins=20,height=15,kde=True)
plt.xlabel('Insulin Level for people')
plt.ylabel('Count of people')
plt.title('No of people having diabetes with certain level of Insuln')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.displot(x = 'DiabetesPedigreeFunction', hue='Outcome', data=df, bins=30,height=15,kde=True)
plt.xlabel('People with DiabetesPedigreeFunction')
plt.ylabel('Frequency of people')
plt.title('Count of people having Diabetes with DiabetesPedigreeFunction')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.displot(x='Glucose',hue='Outcome',bins = 30, kde = True, height = 10,data=df)
plt.xlabel('Glucose Level of People')
plt.ylabel('Count of people')
plt.title('Count of people with certain level of Glucose having diabetes')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(12,8))
sns.displot(data=df,x='Pregnancies',hue='Outcome',bins=30,height=10,kde=True)
plt.xlabel('No of Pregnancies')
plt.ylabel('No of people')
plt.title('No of pregnancies propably causing from diabetes')
plt.show()

# %% [markdown]
# ### 3.Multivariate Analysis

# %%
df['Glucose_bin']=pd.cut(df['Glucose'],bins=10)
df['Insulin_bin']=pd.cut(df['Insulin'],bins=10)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome     Glucose_bin     Insulin_bin
# 0                       0.627   50        1  (139.3, 159.2]  (-0.846, 84.6]
# 1                       0.351   31        0    (79.6, 99.5]  (-0.846, 84.6]
# 2                       0.672   32        1  (179.1, 199.0]  (-0.846, 84.6]
# 3                       0.167   21        0    (79.6, 99.5]   (84.6, 169.2]
# 4                       2.288   33        1  (119.4, 139.3]   (84.6, 169.2]
# ..                        ...  ...      ...             ...             ...
# 763                     0.171   63        0   (99.5, 119.4]  (169.2, 253.8]
# 764                     0.340   27        0  (119.4, 139.3]  (-0.846, 84.6]
# 765                     0.245   30        0  (119.4, 139.3]   (84.6, 169.2]
# 766                     0.349   47        1  (119.4, 139.3]  (-0.846, 84.6]
# 767                     0.315   23        0    (79.6, 99.5]  (-0.846, 84.6]
#
# [768 rows x 11 columns]

# %%
pivot = df.pivot_table(values='Age',index='Glucose_bin',columns='Insulin_bin',aggfunc='mean')
pivot
# Out:
# C:\Users\91809\AppData\Local\Temp\ipykernel_21484\1825313197.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = df.pivot_table(values='Age',index='Glucose_bin',columns='Insulin_bin',aggfunc='mean')
# Insulin_bin     (-0.846, 84.6]  (84.6, 169.2]  (169.2, 253.8]  (253.8, 338.4]  \
# Glucose_bin
# (-0.199, 19.9]       28.600000            NaN             NaN             NaN
# (39.8, 59.7]         41.500000            NaN             NaN             NaN
# (59.7, 79.6]         29.870968      26.000000             NaN             NaN
# (79.6, 99.5]         29.063492      25.500000       37.000000       44.000000
# (99.5, 119.4]        32.692857      27.702128       34.150000       25.000000
# (119.4, 139.3]       37.651163      32.133333       27.454545       30.200000
# (139.3, 159.2]       39.022222      37.700000       37.727273       34.300000
# (159.2, 179.1]       40.925926      34.692308       40.571429       45.500000
# (179.1, 199.0]       40.130435      41.333333       38.000000       34.666667
#
# Insulin_bin     (338.4, 423.0]  (423.0, 507.6]  (507.6, 592.2]  \
# Glucose_bin
# (-0.199, 19.9]             NaN             NaN             NaN
# (39.8, 59.7]               NaN             NaN             NaN
# (59.7, 79.6]               NaN             NaN             NaN
# (79.6, 99.5]               NaN             NaN             NaN
# (99.5, 119.4]              NaN             NaN             NaN
# (119.4, 139.3]       33.666667       21.000000             NaN
# (139.3, 159.2]       31.666667       35.500000            29.5
# (159.2, 179.1]             NaN       22.666667            28.0
# (179.1, 199.0]       29.000000       60.000000            39.5
#
# Insulin_bin     (592.2, 676.8]  (676.8, 761.4]  (761.4, 846.0]
# Glucose_bin
# (-0.199, 19.9]             NaN             NaN             NaN
# (39.8, 59.7]               NaN             NaN             NaN
# (59.7, 79.6]               NaN             NaN             NaN
# (79.6, 99.5]               NaN             NaN             NaN
# (99.5, 119.4]              NaN             NaN             NaN
# (119.4, 139.3]            52.0             NaN             NaN
# (139.3, 159.2]             NaN             NaN             NaN
# (159.2, 179.1]             NaN            23.0             NaN
# (179.1, 199.0]             NaN            31.0            59.0

# %%
plt.figure(figsize=(12,6))
sns.heatmap(pivot,annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df[['Glucose','Insulin','Age','BMI']],diag_kind='kde')
plt.show()

# %%
sns.heatmap(df[['Glucose','Insulin','Age','BMI']].corr(),annot=True)
plt.show()

# %%
sns.pairplot(df[['Glucose','Insulin','DiabetesPedigreeFunction']],diag_kind=True)
plt.show()

# %%
df['DiabetesPedigreeFunction_bin'] = pd.cut(df['DiabetesPedigreeFunction'],bins=10)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome     Glucose_bin     Insulin_bin  \
# 0                       0.627   50        1  (139.3, 159.2]  (-0.846, 84.6]
# 1                       0.351   31        0    (79.6, 99.5]  (-0.846, 84.6]
# 2                       0.672   32        1  (179.1, 199.0]  (-0.846, 84.6]
# 3                       0.167   21        0    (79.6, 99.5]   (84.6, 169.2]
# 4                       2.288   33        1  (119.4, 139.3]   (84.6, 169.2]
# ..                        ...  ...      ...             ...             ...
# 763                     0.171   63        0   (99.5, 119.4]  (169.2, 253.8]
# 764                     0.340   27        0  (119.4, 139.3]  (-0.846, 84.6]
# 765                     0.245   30        0  (119.4, 139.3]   (84.6, 169.2]
# 766                     0.349   47        1  (119.4, 139.3]  (-0.846, 84.6]
# 767                     0.315   23        0    (79.6, 99.5]  (-0.846, 84.6]
#
#     DiabetesPedigreeFunction_bin
# 0                 (0.546, 0.781]
# 1                 (0.312, 0.546]
# 2                 (0.546, 0.781]
# 3                (0.0757, 0.312]
# 4                  (2.186, 2.42]
# ..                           ...
# 763              (0.0757, 0.312]
# 764               (0.312, 0.546]
# 765              (0.0757, 0.312]
# 766               (0.312, 0.546]
# 767               (0.312, 0.546]
#
# [768 rows x 12 columns]

# %%
pivot_table = df.pivot_table(values='Age', index = 'DiabetesPedigreeFunction_bin',columns='Glucose_bin',aggfunc='mean')
pivot_table
# Out:
# C:\Users\91809\AppData\Local\Temp\ipykernel_21484\2446117339.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = df.pivot_table(values='Age', index = 'DiabetesPedigreeFunction_bin',columns='Glucose_bin',aggfunc='mean')
# Glucose_bin                   (-0.199, 19.9]  (39.8, 59.7]  (59.7, 79.6]  \
# DiabetesPedigreeFunction_bin
# (0.0757, 0.312]                         21.5          41.0     32.437500
# (0.312, 0.546]                          29.5          22.0     26.222222
# (0.546, 0.781]                          41.0          51.5     28.833333
# (0.781, 1.015]                           NaN           NaN           NaN
# (1.015, 1.249]                           NaN           NaN           NaN
# (1.249, 1.483]                           NaN           NaN     24.000000
# (1.483, 1.717]                           NaN           NaN           NaN
# (1.717, 1.952]                           NaN           NaN           NaN
# (1.952, 2.186]                           NaN           NaN           NaN
# (2.186, 2.42]                            NaN           NaN           NaN
#
# Glucose_bin                   (79.6, 99.5]  (99.5, 119.4]  (119.4, 139.3]  \
# DiabetesPedigreeFunction_bin
# (0.0757, 0.312]                  27.784615      31.163265       35.362319
# (0.312, 0.546]                   28.500000      30.061224       32.133333
# (0.546, 0.781]                   28.961538      31.156250       38.615385
# (0.781, 1.015]                   36.375000      34.043478       28.818182
# (1.015, 1.249]                   31.400000      38.333333       33.285714
# (1.249, 1.483]                   26.000000      43.800000       38.333333
# (1.483, 1.717]                   26.500000            NaN       25.000000
# (1.717, 1.952]                         NaN      21.000000             NaN
# (1.952, 2.186]                         NaN            NaN             NaN
# (2.186, 2.42]                          NaN            NaN       33.000000
#
# Glucose_bin                   (139.3, 159.2]  (159.2, 179.1]  (179.1, 199.0]
# DiabetesPedigreeFunction_bin
# (0.0757, 0.312]                    39.114286       42.947368       41.230769
# (0.312, 0.546]                     36.384615       34.333333       37.818182
# (0.546, 0.781]                     36.047619       35.363636       43.818182
# (0.781, 1.015]                     36.750000       38.666667       31.500000
# (1.015, 1.249]                     34.333333       41.000000       47.000000
# (1.249, 1.483]                     51.000000             NaN       29.666667
# (1.483, 1.717]                           NaN             NaN             NaN
# (1.717, 1.952]                     44.000000             NaN       25.000000
# (1.952, 2.186]                           NaN       25.000000             NaN
# (2.186, 2.42]                            NaN             NaN       28.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(pivot_table,annot = True)
# Out:
# <Axes: xlabel='Glucose_bin', ylabel='DiabetesPedigreeFunction_bin'>
